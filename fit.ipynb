# %%
from GrowthFit import GrowthFit

file_name = 'HeLa.xlsx'

hela_gf = GrowthFit(file_name)
hela_gf.fit(sigma=1)
hela_gf.export()
#hela_gf.plot(show=False)
#hela_gf.get_survival_fraction(max_slope=False,delay_time=0)
hela_gf.plot_together([2,3])

# %%
from GrowthFit import GrowthFit

file_name = 'CAF.xlsx'

CAF_gf = GrowthFit(file_name)
CAF_gf.fit(sigma=1)
CAF_gf.export()
hela_gf.plot_together([2,3])
# Out:
# 1.3609022973347076
# {'0 Gy - No Gold': {'SF': 0.9999984292108678,
#   'error': 0.1688141674650996,
#   'dt': 3.214873658111791},
#  '0 Gy - Gold': {'SF': 1.1453150534677667,
#   'error': 0.1933457109417486,
#   'dt': 3.214873658111791},
#  '2 Gy - No Gold': {'SF': 0.8535128256993665,
#   'error': 0.14408528341882054,
#   'dt': 3.214873658111791},
#  '2 Gy - Gold': {'SF': 0.7966368703258435,
#   'error': 0.1344838012817533,
#   'dt': 3.214873658111791}}

# %%
from GrowthFit import GrowthFit

file_name = 'Fibro.xlsx'

fibro_gf = GrowthFit(file_name)
fibro_gf.fit(sigma=1)
fibro_gf.export()
fibro_gf.plot(show=False)
fibro_gf.get_survival_fraction(max_slope=False,delay_time=0)
# Out:
# 1.6517259063539151
# {'0 Gy - No Gold': {'SF': 1.000001698543591,
#   'error': 0.1868930408669623,
#   'dt': 2.0371686223800456},
#  '0 Gy - Gold': {'SF': 0.7858532302878204,
#   'error': 0.14687025041809337,
#   'dt': 2.0371686223800456},
#  '2 Gy - No Gold': {'SF': 0.5283528781470767,
#   'error': 0.09874530832450815,
#   'dt': 2.0371686223800456},
#  '2 Gy - Gold': {'SF': 0.3320999789691602,
#   'error': 0.06206706951777743,
#   'dt': 2.0371686223800456}}
